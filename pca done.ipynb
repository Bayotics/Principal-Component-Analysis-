# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rent_lagos_updated.csv')
df
# Out:
#                         housing_type  bedrooms  bathrooms  guest_toilet  \
# 0                   flat / apartment         3          3             0
# 1                   flat / apartment         3          3             0
# 2                   flat / apartment         3          3             1
# 3                   flat / apartment         3          3             0
# 4                   flat / apartment         3          3             0
# ...                              ...       ...        ...           ...
# 20127  mini flat (room and parlour)          1          1             0
# 20128               flat / apartment         2          2             0
# 20129  mini flat (room and parlour)          1          1             0
# 20130               flat / apartment         2          2             0
# 20131               flat / apartment         3          3             1
#
#        parking_space    district  \
# 0                  3  ketu ikosi
# ...

# %%
df = df.drop(columns = ['housing_type', 'bathrooms', 'guest_toilet', 'parking_space', 'district', 'address', 'local government'])
df
# Out:
#        bedrooms  rent_per_annum  districtID
# 0             3     150000000.0          31
# 1             3     600000000.0          25
# 2             3     350000000.0          13
# 3             3     350000000.0          35
# 4             3     350000000.0          35
# ...         ...             ...         ...
# 20127         1        100000.0          23
# 20128         2        100000.0          35
# 20129         1         90000.0          23
# 20130         2         90000.0          25
# 20131         3         85000.0          35
#
# [20132 rows x 3 columns]

# %%
df['budget'] = np.random.randint(80000, 5000000, df.shape[0])
df['cooking'] = np.random.randint(1, 5, df.shape[0])
df['leavehome'] = np.random.randint(1, 4, df.shape[0])
df['religion'] = np.random.randint(1, 3, df.shape[0])
df['sound'] = np.random.randint(1, 4, df.shape[0])
df['workout'] = np.random.randint(1,4, df.shape[0])
df
# Out:
#        bedrooms  rent_per_annum  districtID   budget  cooking  leavehome  \
# 0             3     150000000.0          31  3873593        2          3
# 1             3     600000000.0          25  2155319        1          3
# 2             3     350000000.0          13  4441233        1          1
# 3             3     350000000.0          35  2287976        2          3
# 4             3     350000000.0          35  1127473        3          3
# ...         ...             ...         ...      ...      ...        ...
# 20127         1        100000.0          23  3429653        3          3
# 20128         2        100000.0          35  2771311        1          2
# 20129         1         90000.0          23  2667379        3          3
# 20130         2         90000.0          25  3151397        2          3
# 20131         3         85000.0          35  2190888        3          3
#
#        religion  sound  workout
# 0             1      3        1
# ...

# %%
df = df.round({'budget':-4})
df
# Out:
#        bedrooms  rent_per_annum  districtID   budget  cooking  leavehome  \
# 0             3     150000000.0          31  3870000        2          3
# 1             3     600000000.0          25  2160000        1          3
# 2             3     350000000.0          13  4440000        1          1
# 3             3     350000000.0          35  2290000        2          3
# 4             3     350000000.0          35  1130000        3          3
# ...         ...             ...         ...      ...      ...        ...
# 20127         1        100000.0          23  3430000        3          3
# 20128         2        100000.0          35  2770000        1          2
# 20129         1         90000.0          23  2670000        3          3
# 20130         2         90000.0          25  3150000        2          3
# 20131         3         85000.0          35  2190000        3          3
#
#        religion  sound  workout
# 0             1      3        1
# ...

# %%
newDataset = df.drop(columns = ['rent_per_annum', 'bedrooms', 'districtID'])
newDataset
# Out:
#         budget  cooking  leavehome  religion  sound  workout
# 0      3870000        2          3         1      3        1
# 1      2160000        1          3         1      1        3
# 2      4440000        1          1         1      1        1
# 3      2290000        2          3         2      1        3
# 4      1130000        3          3         2      2        2
# ...        ...      ...        ...       ...    ...      ...
# 20127  3430000        3          3         1      3        3
# 20128  2770000        1          2         2      2        3
# 20129  2670000        3          3         1      3        2
# 20130  3150000        2          3         2      1        2
# 20131  2190000        3          3         1      3        3
#
# [20132 rows x 6 columns]

# %%
def immigrants_segment(value):
    if 80000 <= value < 300000:
        return 1
    elif 300000 <= value < 600000:
        return 2
    elif 600000 <= value < 1000000:
        return 3
    elif value > 1000000:
        return 4

newDataset['immigrants_segment'] = newDataset['budget'].map(immigrants_segment)
newDataset
# Out:
#         budget  cooking  leavehome  religion  sound  workout  \
# 0      3870000        2          3         1      3        1
# 1      2160000        1          3         1      1        3
# 2      4440000        1          1         1      1        1
# 3      2290000        2          3         2      1        3
# 4      1130000        3          3         2      2        2
# ...        ...      ...        ...       ...    ...      ...
# 20127  3430000        3          3         1      3        3
# 20128  2770000        1          2         2      2        3
# 20129  2670000        3          3         1      3        2
# 20130  3150000        2          3         2      1        2
# 20131  2190000        3          3         1      3        3
#
#        immigrants_segment
# 0                     4.0
# 1                     4.0
# 2                     4.0
# 3                     4.0
# 4                     4.0
# ...                   ...
# 20127                 4.0
# ...

# %%
newDataset.fillna('')
# Out:
#         budget  cooking  leavehome  religion  sound  workout  \
# 0      3870000        2          3         1      3        1
# 1      2160000        1          3         1      1        3
# 2      4440000        1          1         1      1        1
# 3      2290000        2          3         2      1        3
# 4      1130000        3          3         2      2        2
# ...        ...      ...        ...       ...    ...      ...
# 20127  3430000        3          3         1      3        3
# 20128  2770000        1          2         2      2        3
# 20129  2670000        3          3         1      3        2
# 20130  3150000        2          3         2      1        2
# 20131  2190000        3          3         1      3        3
#
#       immigrants_segment
# 0                    4.0
# 1                    4.0
# 2                    4.0
# 3                    4.0
# 4                    4.0
# ...                  ...
# 20127                4.0
# ...

# %%
n = 100
newDataset = newDataset.iloc[:n] 
newDataset
# Out:
#      budget  cooking  leavehome  religion  sound  workout  immigrants_segment
# 0   3870000        2          3         1      3        1                 4.0
# 1   2160000        1          3         1      1        3                 4.0
# 2   4440000        1          1         1      1        1                 4.0
# 3   2290000        2          3         2      1        3                 4.0
# 4   1130000        3          3         2      2        2                 4.0
# ..      ...      ...        ...       ...    ...      ...                 ...
# 95  1250000        4          2         2      2        2                 4.0
# 96  3010000        2          3         1      1        1                 4.0
# 97  2790000        2          3         2      2        3                 4.0
# 98  3910000        3          1         1      3        2                 4.0
# 99  3020000        2          1         1      3        2                 4.0
#
# [100 rows x 7 columns]

# %%
x = newDataset.iloc[:, 0:6].values
y = newDataset.iloc[:, 6].values

# %%
x
# Out:
# array([[3870000,       2,       3,       1,       3,       1],
#        [2160000,       1,       3,       1,       1,       3],
#        [4440000,       1,       1,       1,       1,       1],
#        [2290000,       2,       3,       2,       1,       3],
#        [1130000,       3,       3,       2,       2,       2],
#        [4300000,       2,       1,       1,       2,       3],
#        [3720000,       3,       3,       1,       2,       3],
#        [1820000,       4,       3,       2,       3,       1],
#        [3340000,       2,       2,       1,       2,       2],
#        [2850000,       2,       2,       2,       2,       3],
#        [1570000,       4,       2,       1,       3,       3],
#        [1590000,       2,       1,       1,       1,       2],
#        [1470000,       4,       3,       1,       2,       1],
#        [4170000,       1,       2,       2,       2,       1],
#        [4390000,       2,       3,       2,       3,       3],
# ...

# %%
y
# Out:
# array([4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3.,
#        2., 4., 4., 3., 4., 2., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 3., 4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 4., 3., 4., 4.,
#        4., 2., 4., 4., 2., 4., 4., 4., 4., 4., 4., 4., 2., 4., 4., 4., 4.,
#        3., 4., 3., 4., 4., 4., 4., 1., 4., 4., 4., 4., 4., 4., 4.])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
# array([[ 660000,       3,       3,       2,       1,       3],
#        [3430000,       3,       1,       1,       1,       3],
#        [2290000,       2,       3,       2,       1,       3],
#        [4480000,       4,       2,       2,       2,       3],
#        [3460000,       3,       3,       2,       3,       3],
#        [3210000,       4,       2,       1,       2,       2],
#        [3720000,       3,       3,       1,       2,       3],
#        [3020000,       2,       1,       1,       3,       2],
#        [2170000,       3,       2,       2,       2,       3],
#        [3920000,       2,       3,       1,       2,       1],
#        [ 990000,       4,       1,       2,       3,       3],
#        [ 480000,       4,       3,       2,       3,       1],
#        [4160000,       4,       2,       2,       2,       2],
#        [4830000,       1,       2,       1,       3,       2],
#        [1900000,       3,       2,       2,       3,       2],
# ...

# %%
x_test
# Out:
# array([[4520000,       2,       3,       2,       2,       3],
#        [1210000,       1,       2,       1,       2,       1],
#        [4440000,       1,       1,       1,       1,       1],
#        [3310000,       1,       2,       2,       2,       2],
#        [4990000,       1,       1,       1,       3,       2],
#        [1760000,       4,       3,       2,       1,       2],
#        [ 630000,       3,       3,       2,       2,       1],
#        [3160000,       4,       3,       2,       3,       1],
#        [2580000,       4,       2,       1,       1,       2],
#        [1250000,       4,       2,       2,       2,       2],
#        [ 810000,       4,       1,       1,       3,       2],
#        [ 110000,       1,       2,       1,       1,       3],
#        [1410000,       3,       1,       1,       3,       2],
#        [4170000,       1,       2,       2,       2,       1],
#        [1820000,       4,       3,       2,       3,       1],
# ...

# %%
y_train
# Out:
# array([3., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 2., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 2., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 2., 3., 4., 2., 4., 4., 4., 4., 4., 4., 3., 4., 4.,
#        4., 4., 3., 4., 4., 4., 4., 4., 4., 4., 4., 4.])

# %%
y_test
# Out:
# array([4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 3., 1., 4., 4., 4., 4., 2.,
#        4., 4., 4.])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)

# %%
x_train.shape
# Out:
# (80, 2)

# %%
y_train.shape
# Out:
# (80,)

# %%
x = x.transpose() 
y_train.shape
# Out:
# (80,)

# %%
missing_labels = np.isnan(y_train)
print("Number of missing labels:", np.sum(missing_labels))
# Out:
# Number of missing labels: 0

# %%
y_train
# Out:
# array([3., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 2., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 2., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 2., 3., 4., 2., 4., 4., 4., 4., 4., 4., 3., 4., 4.,
#        4., 4., 3., 4., 4., 4., 4., 4., 4., 4., 4., 4.])

# %%
y
# Out:
# array([4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3.,
#        2., 4., 4., 3., 4., 2., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 3., 4., 4., 4., 4., 4., 4., 3., 4., 4., 4., 4., 3., 4., 4.,
#        4., 2., 4., 4., 2., 4., 4., 4., 4., 4., 4., 4., 2., 4., 4., 4., 4.,
#        3., 4., 3., 4., 4., 4., 4., 1., 4., 4., 4., 4., 4., 4., 4.])

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[ 0  0  0  1]
#  [ 0  0  0  1]
#  [ 0  0  0  2]
#  [ 0  0  1 15]]
# 0.75

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_test, y_test
x1, x2 = np.meshgrid(np.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))
plt.contourf(x1, x2, classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green', 'blue')))
plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],
                c = ListedColormap(('red', 'green', 'blue'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17688\894739328.py:10: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],
# <function matplotlib.pyplot.legend(*args, **kwargs)>
